# %%
import pickle
import pandas as po

# %%
with open('outputs/results/energy_consumption/output_map.pkl',  'rb') as pred_file:
    output_map = pickle.load(pred_file)
    
with open('outputs/results/energy_consumption/p50_forecast.pkl', 'rb') as pred_file:
    p50_forecast = pickle.load(pred_file)  
  
with open('outputs/results/energy_consumption/p90_forecast.pkl', 'rb') as pred_file:
    p90_forecast = pickle.load(pred_file)

# %%
output_map.keys()
# Out:
# dict_keys(['p10', 'p50', 'p90', 'targets'])

# %%
df = po.read_csv('outputs/data/energy_consumption/energy.csv')

# %%
train = df[:int(0.65*len(df))]
valid = df[int(0.65*len(df)):int(0.8*len(df))]
test = df[int(0.8*len(df)):]

# %%
output_map['targets']
# Out:
#    forecast_time identifier       t+0       t+1
# 0      20/7/2019     Energy -0.769698 -0.921443
# 1      21/7/2019     Energy -0.921443 -1.633921
# 2      22/7/2019     Energy -1.633921 -1.080550
# 3      23/7/2019     Energy -1.080550 -0.795705
# 4      24/7/2019     Energy -0.795705 -0.595450
# 5      25/7/2019     Energy -0.595450 -0.565897
# 6      26/7/2019     Energy -0.565897 -1.714142
# 7      27/7/2019     Energy -1.714142 -1.955248
# 8      28/7/2019     Energy -1.955248 -1.589723
# 9      29/7/2019     Energy -1.589723 -1.430253
# 10     30/7/2019     Energy -1.430253 -1.219523
# 11     31/7/2019     Energy -1.219523 -0.980763
# 12      1/8/2019     Energy -0.980763 -0.873940
# 13      2/8/2019     Energy -0.873940 -1.236565
# 14      3/8/2019     Energy -1.236565 -1.662873
# 15      4/8/2019     Energy -1.662873 -1.390550
# 16      5/8/2019     Energy -1.390550 -1.071775
# 17      6/8/2019     Energy -1.071775 -0.719051
# 18      7/8/2019     Energy -0.719051 -0.372659
# ...

# %%
p50_forecast
# Out:
#    forecast_time identifier       t+0       t+1
# 0      20/7/2019     Energy -0.205419 -0.196519
# 1      21/7/2019     Energy -0.250560 -0.225199
# 2      22/7/2019     Energy -0.255743 -0.222295
# 3      23/7/2019     Energy -0.250681 -0.228463
# 4      24/7/2019     Energy -0.253723 -0.251733
# 5      25/7/2019     Energy -0.243363 -0.202283
# 6      26/7/2019     Energy -0.184781 -0.215766
# 7      27/7/2019     Energy -0.201339 -0.223324
# 8      28/7/2019     Energy -0.289927 -0.282089
# 9      29/7/2019     Energy -0.302293 -0.265244
# 10     30/7/2019     Energy -0.274481 -0.238817
# 11     31/7/2019     Energy -0.285338 -0.281104
# 12      1/8/2019     Energy -0.301413 -0.275796
# 13      2/8/2019     Energy -0.278632 -0.296452
# 14      3/8/2019     Energy -0.278704 -0.281786
# 15      4/8/2019     Energy -0.301828 -0.272077
# 16      5/8/2019     Energy -0.284507 -0.260448
# 17      6/8/2019     Energy -0.287875 -0.252720
# 18      7/8/2019     Energy -0.275607 -0.272298
# ...

# %%
import matplotlib.pyplot as plt

# %%
output_map.keys()
# Out:
# dict_keys(['p10', 'p50', 'p90', 'targets'])

# %%
#plt.plot(output_map['p10']['t+1'])
#plt.plot(output_map['p50']['t+1'])
#plt.plot(output_map['p50']['t+1'], color = 'blue')
plt.plot(output_map['p90']['t+1'], color = 'blue')
plt.plot(output_map['targets']['t+1'], color = 'red')

# %% [markdown]
# with open('outputs/results/energy_consumption/output_map_5_2.pkl',  'wb') as pred_file:
#     pickle.dump(output_map, pred_file)

# %%
with open('outputs/results/energy_consumption/output_map_30_7.pkl',  'rb') as pred_file:
    output_map_30_7 = pickle.load(pred_file)

# %%
plt.plot(output_map_30_7['p90']['t+1'], color = 'blue')
plt.plot(output_map_30_7['targets']['t+1'], color = 'red')

# %%
with open('outputs/results/energy_consumption/output_map_5_2.pkl',  'rb') as pred_file:
    output_map = pickle.load(pred_file)
plt.plot(output_map['p75']['t+1'], color = 'blue')
#plt.plot(output_map['p50']['t+1'], color = 'black')
plt.plot(output_map['targets']['t+1'], color = 'red')

# %%
with open('outputs/results/energy_consumption/output_map_5_2_500.pkl',  'rb') as pred_file:
    output_map = pickle.load(pred_file)
plt.plot(output_map['p75']['t+1'], color = 'blue')
#plt.plot(output_map['p50']['t+1'], color = 'black')
plt.plot(output_map['targets']['t+1'], color = 'red')

# %%
with open('outputs/results/energy_consumption/output_map_5_2_100.pkl',  'rb') as pred_file:
    output_map = pickle.load(pred_file)
plt.plot(output_map['p75']['t+1'], color = 'blue')
#plt.plot(output_map['p50']['t+1'], color = 'black')
plt.plot(output_map['targets']['t+1'], color = 'red')
#P75=0.4052748641693289

# %%
with open('outputs/results/energy_consumption/output_map_5_2_200.pkl',  'rb') as pred_file:
    output_map = pickle.load(pred_file)
plt.plot(output_map['p75']['t+1'], color = 'blue')
#plt.plot(output_map['p50']['t+1'], color = 'black')
plt.plot(output_map['targets']['t+1'], color = 'red')
#P75=0.2797208411394473

# %%
with open('outputs/results/energy_consumption/output_map_5_2_150.pkl',  'rb') as pred_file:
    output_map = pickle.load(pred_file)
plt.plot(output_map['p75']['t+1'], color = 'blue')
#plt.plot(output_map['p50']['t+1'], color = 'black')
plt.plot(output_map['targets']['t+1'], color = 'red')
#P75=0.2797208411394473

# %%
with open('outputs/results/energy_consumption/output_map_5_2_160.pkl',  'rb') as pred_file:
    output_map = pickle.load(pred_file)
plt.plot(output_map['p75']['t+1'], color = 'blue')
#plt.plot(output_map['p50']['t+1'], color = 'black')
plt.plot(output_map['targets']['t+1'], color = 'red')
#P75=0.4185459236717775
