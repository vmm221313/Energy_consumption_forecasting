# %%
# !git clone https://github.com/vmm221313/Energy_consumption_forecasting
# Out:
# Cloning into 'Energy_consumption_forecasting'...
# remote: Enumerating objects: 181, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 181 (delta 52), reused 170 (delta 41), pack-reused 0
# Receiving objects: 100% (181/181), 50.36 MiB | 24.34 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# Checking out files: 100% (150/150), done.

# %%
cd Energy_consumption_forecasting/Temporal-Fusion-Transformer/
# Out:
# /content/Energy_consumption_forecasting/Temporal-Fusion-Transformer

# %%
#cd drive/My\ Drive/Projects/TemporalFusionTransformer
# Out:
# /content/drive/My Drive/Projects/TemporalFusionTransformer

# %%
ls
# Out:
# Analyse-Predictions.ipynb  libs/                requirements.txt
# BEST_PARAMS.png            outputs/             run.sh*
# data/                      playground.ipynb     script_download_data.py
# data_formatters/           preprocessing.ipynb  script_hyperparam_opt.py
# expt_settings/             __pycache__/         script_train_fixed_params.py
# formatted_omi_vol.csv      README.md

# %%
# !pip install pyunpack

# %%
# !pip install wget

# %%
# !pip3 install --pre "tensorflow==1.15.*"

# %%
#Uncomment to tune hyperparameters. (WARNING: will run for several hours)
#!python3 -m script_hyperparam_opt energy_consumption outputs no no
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59
# Using output folder outputs
# WARNING:tensorflow:From /content/drive/My Drive/Projects/TemporalFusionTransformer/script_hyperparam_opt.py:61: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
#
# 2020-03-25 09:42:41.119927: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-25 09:42:41.133378: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-25 09:42:41.134016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# ...

# %%
# !python3 -m script_train_fixed_params energy_consumption outputs no
# Out:
# Streaming output truncated to the last 5000 lines.
#  [ 0.18356991]
#  [-0.07044972]
#  [-0.05833168]
#  [ 0.15028846]
#  [-0.10397028]
#  [-0.18448403]
#  [ 0.03157504]
#  [ 0.14681837]
#  [-0.02908932]
#  [-0.01712547]
#  [-0.06568962]
#  [-0.03772296]
#  [ 0.02445686]
#  [ 0.16787893]
#  [ 0.11298335]
#  [-0.12501924]
#  [-0.05578391]
#  [-0.06674495]
#  [-0.1821346 ]
#  [-0.07420539]
#  [ 0.12770012]
#  [ 0.02381286]
#  [-0.0339497 ]
#  [-0.12953834]
#  [ 0.04261294]
#  [ 0.07181591]
#  [ 0.07716748]
#  [-0.00110233]
#  [-0.1367471 ]
#  [ 0.06527036]
#  [ 0.059921  ]
#  [-0.13314074]
#  [ 0.18355623]
#  [ 0.04819883]
#  [-0.19026673]
#  [ 0.0043413 ]
#  [ 0.04900479]
#  [ 0.02143626]
#  [-0.11188739]
#  [-0.07702503]
#  [ 0.15723398]
#  [-0.10859787]
#  [-0.18135238]
#  [ 0.1887883 ]
#  [-0.09799358]
#  [ 0.02193947]
#  [ 0.07169968]
#  [-0.13414246]
#  [ 0.12602651]
#  [-0.07888807]
#  [ 0.14250344]
#  [ 0.07894129]
#  [-0.02502918]
#  [ 0.13783023]
#  [ 0.02669239]
# ...

# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open('outputs/results/energy_consumption/output_map_5_2.pkl',  'rb') as pred_file:
    output_map = pickle.load(pred_file)
plt.plot(output_map['p75']['t+1'], color = 'blue')
plt.plot(output_map['targets']['t+1'], color = 'red')
